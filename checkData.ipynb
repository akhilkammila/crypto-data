# %%
import pandas as pd

# %%
interval = 5
directoryMap = {
    1: 'minute',
    5: '5minute',
    60: 'hourly',
    'D': 'daily'
    }

df = pd.read_csv(f"./{directoryMap[interval]}Data/crypto_data.csv")
df.head()
# Out:
#                   time  CATIUSDT_open  CATIUSDT_high  CATIUSDT_low  \
# 0  2024-09-01 00:00:00            NaN            NaN           NaN
# 1  2024-09-01 00:05:00            NaN            NaN           NaN
# 2  2024-09-01 00:10:00            NaN            NaN           NaN
# 3  2024-09-01 00:15:00            NaN            NaN           NaN
# 4  2024-09-01 00:20:00            NaN            NaN           NaN
#
#    CATIUSDT_close  CATIUSDT_volume  CATIUSDT_turnover  ETH-29NOV24_open  \
# 0             NaN              NaN                NaN               NaN
# 1             NaN              NaN                NaN               NaN
# 2             NaN              NaN                NaN               NaN
# 3             NaN              NaN                NaN               NaN
# 4             NaN              NaN                NaN               NaN
#
#    ETH-29NOV24_high  ETH-29NOV24_low  ...  CTCUSDT_low  CTCUSDT_close  \
# ...
